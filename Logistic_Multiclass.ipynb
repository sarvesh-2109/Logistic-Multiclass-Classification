# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix
import seaborn as sns

# %%
iris = load_iris()

# %%
for i in range(5):
  plt.plot(iris.data[i].reshape(4,1))

# %%
dir(iris)
# Out:
# ['DESCR',
#  'data',
#  'data_module',
#  'feature_names',
#  'filename',
#  'frame',
#  'target',
#  'target_names']

# %% [markdown]
# ## Creating and training logistic regression model

# %%
model = LogisticRegression(max_iter=1000)

# %%
X_train, X_test, y_train, y_test = train_test_split(iris.data, iris.target, test_size=0.2)

# %%
model.fit(X_train, y_train)
# Out:
# LogisticRegression(max_iter=1000)

# %% [markdown]
# ## Measuring accuracy of our model

# %%
model.score(X_test, y_test)
# Out:
# 0.9333333333333333

# %% [markdown]
# ## Confusion matrix

# %%
y_pred = model.predict(X_test)

# %%
cm = confusion_matrix(y_test, y_pred)
cm
# Out:
# array([[11,  0,  0],
#        [ 0,  6,  0],
#        [ 0,  2, 11]])

# %%
plt.figure(figsize = (10,7))
sns.heatmap(cm, annot=True)
plt.xlabel('Predicted')
plt.ylabel('Truth')
# Out:
# Text(95.72222222222221, 0.5, 'Truth')

# %%
for i in range(len(X_test)):
    print(f'Sample {i+1}:')
    print(f'Features: {X_test[i]}')
    print(f'Predicted Label: {iris.target_names[y_pred[i]]}')
    print(f'Actual Label: {iris.target_names[y_test[i]]}')
    print()
# Out:
# Sample 1:
# Features: [6.3 2.5 5.  1.9]
# Predicted Label: virginica
# Actual Label: virginica
#
# Sample 2:
# Features: [4.3 3.  1.1 0.1]
# Predicted Label: setosa
# Actual Label: setosa
#
# Sample 3:
# Features: [5.  3.5 1.3 0.3]
# Predicted Label: setosa
# Actual Label: setosa
#
# Sample 4:
# Features: [5.2 3.5 1.5 0.2]
# Predicted Label: setosa
# Actual Label: setosa
#
# Sample 5:
# Features: [6.4 3.2 5.3 2.3]
# Predicted Label: virginica
# Actual Label: virginica
#
# Sample 6:
# Features: [5.  3.5 1.6 0.6]
# Predicted Label: setosa
# Actual Label: setosa
#
# Sample 7:
# Features: [7.2 3.2 6.  1.8]
# Predicted Label: virginica
# Actual Label: virginica
#
# Sample 8:
# Features: [5.4 3.9 1.3 0.4]
# Predicted Label: setosa
# Actual Label: setosa
#
# Sample 9:
# Features: [5.5 2.6 4.4 1.2]
# Predicted Label: versicolor
# Actual Label: versicolor
#
# Sample 10:
# Features: [6.2 2.2 4.5 1.5]
# Predicted Label: versicolor
# Actual Label: versicolor
#
# Sample 11:
# Features: [5.5 2.3 4.  1.3]
# Predicted Label: versicolor
# Actual Label: versicolor
#
# Sample 12:
# Features: [6.7 3.3 5.7 2.1]
# Predicted Label: virginica
# Actual Label: virginica
#
# Sample 13:
# Features: [4.5 2.3 1.3 0.3]
# Predicted Label: setosa
# Actual Label: setosa
#
# Sample 14:
# Features: [6.  2.2 5.  1.5]
# Predicted Label: versicolor
# Actual Label: virginica
#
# Sample 15:
# Features: [7.6 3.  6.6 2.1]
# Predicted Label: virginica
# Actual Label: virginica
#
# Sample 16:
# Features: [6.6 2.9 4.6 1.3]
# Predicted Label: versicolor
# Actual Label: versicolor
#
# Sample 17:
# Features: [6.9 3.1 4.9 1.5]
# Predicted Label: versicolor
# Actual Label: versicolor
#
# Sample 18:
# Features: [4.9 3.6 1.4 0.1]
# Predicted Label: setosa
# Actual Label: setosa
#
# Sample 19:
# Features: [5.9 3.  5.1 1.8]
# Predicted Label: virginica
# Actual Label: virginica
#
# Sample 20:
# Features: [5.  3.6 1.4 0.2]
# Predicted Label: setosa
# Actual Label: setosa
#
# Sample 21:
# Features: [5.8 2.8 5.1 2.4]
# Predicted Label: virginica
# Actual Label: virginica
#
# Sample 22:
# Features: [4.9 3.1 1.5 0.2]
# Predicted Label: setosa
# Actual Label: setosa
#
# Sample 23:
# Features: [5.6 2.8 4.9 2. ]
# Predicted Label: virginica
# Actual Label: virginica
#
# Sample 24:
# Features: [4.8 3.4 1.9 0.2]
# Predicted Label: setosa
# Actual Label: setosa
#
# Sample 25:
# Features: [6.3 2.8 5.1 1.5]
# Predicted Label: versicolor
# Actual Label: virginica
#
# Sample 26:
# Features: [6.  2.2 4.  1. ]
# Predicted Label: versicolor
# Actual Label: versicolor
#
# Sample 27:
# Features: [6.3 2.9 5.6 1.8]
# Predicted Label: virginica
# Actual Label: virginica
#
# Sample 28:
# Features: [4.9 3.1 1.5 0.1]
# Predicted Label: setosa
# Actual Label: setosa
#
# Sample 29:
# Features: [6.5 3.  5.8 2.2]
# Predicted Label: virginica
# Actual Label: virginica
#
# Sample 30:
# Features: [6.5 3.  5.5 1.8]
# Predicted Label: virginica
# Actual Label: virginica
